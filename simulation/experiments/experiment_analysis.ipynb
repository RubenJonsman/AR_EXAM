# %%
survival_times = [3.53214430809021, 51.33624744415283, 22.172515392303467, 9.534963607788086, 5.027225017547607, 28.892643451690674, 29.108580589294434, 60, 45.08566761016846, 20.07113027572632, 20.190458297729492, 60, 7.931483030319214, 22.45859169960022, 41.64706254005432, 60, 15.182785034179688, 58.38031053543091, 60, 52.141786098480225, 19.909799098968506, 53.467692613601685, 10.13238787651062, 1.6970200538635254, 8.91676139831543, 24.580036640167236, 35.85730457305908, 60, 6.731595277786255, 59.42422413825989, 60, 4.00947380065918, 31.266603708267212, 22.126965522766113, 28.611003398895264, 60, 19.643017053604126, 60, 60, 5.816107511520386, 6.773637056350708, 53.939767599105835, 4.082009792327881, 34.97199606895447, 49.12830829620361, 9.355798959732056, 60, 27.818382024765015, 34.22074866294861, 3.6439950466156006, 22.17503333091736, 60, 19.807379245758057, 19.52860116958618, 7.074830532073975, 14.812309503555298, 14.592329263687134, 13.806340456008911, 10.695768117904663, 60, 60, 20.60356068611145, 60, 4.51693058013916, 60, 37.87007260322571, 60, 1.4103710651397705, 38.451239585876465, 3.826162576675415, 60, 37.31489658355713, 60, 15.340313196182251, 6.683992385864258, 21.675519704818726, 19.768569946289062, 8.297046184539795, 20.242391347885132, 60, 24.047903776168823, 60, 60, 44.66344356536865, 14.473021984100342, 60, 8.173545598983765, 5.33608341217041, 57.17039346694946, 60, 60, 5.048649787902832, 60, 60, 7.118843078613281, 60, 25.10627293586731, 7.962471008300781, 60, 60]

# %%
import numpy as np
import matplotlib.pyplot as plt

mean_survival = np.mean(survival_times)
median_survival = np.median(survival_times)
std_survival = np.std(survival_times)

plt.hist(survival_times, bins=30, edgecolor='black')
plt.title('Histogram of Survival Times')
plt.xlabel('Survival Time')
plt.ylabel('Frequency')

# Despline top and right spline
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.axvline(x=mean_survival, color='y', linestyle='-', label=f'Mean: {mean_survival:.2f}')
plt.axvline(x=median_survival, color='c', linestyle='-', label=f'Median: {median_survival:.2f}')
plt.axvline(x=mean_survival + std_survival, color='m', linestyle='--', label=f'Std Dev: {std_survival:.2f}')
plt.axvline(x=mean_survival - std_survival, color='m', linestyle='--')

plt.legend()
plt.savefig("experiment_1_histogram.pdf")
plt.show()
